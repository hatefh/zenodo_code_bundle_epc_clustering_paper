# %% [markdown]
# # Run pipeline
# This notebook calls the scripts to reproduce results.

# %%
# !python code/preprocessing/preprocess_data.py

# %%
# !python code/feature_engineering/extract_features.py

# %%
# !python code/clustering/kmedoids.py
# !python code/clustering/agglomerative.py
# !python code/clustering/gmm.py

# %%
# !python code/validation/validation_metrics.py
